# %%
import json
f = open('dataset.json')
data = json.load(f)

# %%
import pandas as pd

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, ne_chunk

# %%
df = pd.DataFrame(data)

# %%
#df['line'][4341]

#df['line'].sample(1)

#df['tag'].value_counts()

# %%
all_tags = ' '.join(df['line'].tolist())

# %%
df['tokenized'] = df.apply(lambda row: nltk.word_tokenize(row['line'].lower()), axis=1)

# %%
freq_count = {}
for i in df['tokenized']:
    for j in i:
        if j in freq_count:
            freq_count[j] += 1
        else:
            freq_count.update({j:1})

# %%
#sorted(freq_count.items(), key=lambda x:x[1], reverse=True)

# %%
#df['line'][df['line'].str.contains('Docker')]

# %%
#df['bigrams']=df.apply(lambda row: list(nltk.bigrams(row['tokenized'])), axis=1)

# %%
# bigram_freq_count = {}
# for i in df['bigrams']:
#     for j in i:
#         if j in bigram_freq_count:
#             bigram_freq_count[j] += 1
#         else:
#             bigram_freq_count.update({j:1})

# %%
#sorted(bigram_freq_count.items(), key=lambda x:x[1], reverse=True)

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
#df['line'][df['videoId']=='x6Kpkl0C2xg']

# %%
# for vid in df['videoId'].unique():
#     try:
#         transcript_string = ""
#         for text in YouTubeTranscriptApi.get_transcript(vid): transcript_string += " "+text['text']

#         f = open(f"./transcripts/{vid}.txt", "a")
#         f.write(transcript_string)
#         f.close()
#     except:
#         print(vid)

# %%
#nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download("maxent_ne_chunker")
# nltk.download("words")
# nltk.download('averaged_perceptron_tagger')

# %%
# Tokenize the text
tokens = word_tokenize(all_tags)

# Remove stop words
stop_words = set(stopwords.words("english"))
filtered_tokens = [token for token in tokens if token.lower() not in stop_words]

# Stemming
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]


tokens = word_tokenize(all_tags)
pos_tags = pos_tag(tokens)
named_entities = ne_chunk(pos_tags)
# named_entities draws a huge map and cause page to crash
# Result
# print("Original tokens: ", tokens)
# print("Filtered tokens: ", filtered_tokens)
# print("Stemmed tokens: ", stemmed_tokens)
# print("Lemmatized tokens: ", lemmatized_tokens)

# %%
pos_tags
# Out:
# [('Free', 'JJ'),
#  ('HackTheBox', 'NNP'),
#  ('Course', 'NNP'),
#  ('on', 'IN'),
#  ('getting', 'VBG'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('right', 'JJ'),
#  ('mindset', 'NN'),
#  ('to', 'TO'),
#  ('learn', 'VB'),
#  ('.', '.'),
#  ('Free', 'JJ'),
#  ('HackTheBox', 'NNP'),
#  ('Course', 'NNP'),
#  ('on', 'IN'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('Academy', 'NNP'),
#  ('Platform', 'NNP'),
#  ('HackTheBox', 'NNP'),
#  ('Course', 'NNP'),
#  ('on', 'IN'),
#  ('Hacking', 'NNP'),
#  ('Wordpress', 'NNP'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('cost', 'NN'),
#  ('100', 'CD'),
#  ('cubes', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('~', 'JJ'),
#  ('$', '$'),
#  ('10', 'CD'),
#  ('HackTheBox', 'NNP'),
#  ('Course', 'NNP'),
#  ('on', 'IN'),
#  ('using', 'VBG'),
#  ('NMAP', 'NNP'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('fullest', 'JJS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('cost', 'NN'),
#  ('50', 'CD'),
#  ('cubes', 'NN'),
#  (',', ','),
# ...

# %%
from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

# %%
printmd("**bold text**", color="#00FF00")
# Out:
# <span style='color:#00FF00'>**bold text**</span>

# %% [markdown]
# https://www.nltk.org/book/ch05.html
# https://stackoverflow.com/questions/15388831/what-are-all-possible-pos-tags-of-nltk

# %%
nouns = []

for i in pos_tags:
    if i[1] == 'NNP':
        print(i)
# Out:
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Academy', 'NNP')
# ('Platform', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Hacking', 'NNP')
# ('Wordpress', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('NMAP', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Hashcat', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Enumerating', 'NNP')
# ('Active', 'NNP')
# ('Directory', 'NNP')
# ('LDAP', 'NNP')
# ('Free', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Directory', 'NNP')
# ('Traversal', 'NNP')
# ('File', 'NNP')
# ('Inclusion', 'NNP')
# ('Free', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('HTTP', 'NNP')
# ('Web', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Javascript', 'NNP')
# ('Coding', 'NNP')
# ('Free', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Deobfuscating', 'NNP')
# ('Javascript', 'NNP')
# ('HackTheBox', 'NNP')
# ('Course', 'NNP')
# ('Command', 'NNP')
# ...

# %%
asd = {1:"a"}

# %%
1 in asd
# Out:
# True

# %%
count_dict = {}
for i in pos_tags:
    if i[1] in count_dict:
        count_dict[i[1]] += 1
    else:
        count_dict.update({i[1]:1})

# %%
sorted(count_dict.items(), key = lambda x: x[1], reverse=True)
# Out:
# [('NNP', 12457),
#  ('NN', 10584),
#  ('DT', 6843),
#  ('IN', 5956),
#  ('VBG', 5926),
#  ('VB', 4117),
#  ('TO', 3700),
#  ('JJ', 3014),
#  ('NNS', 2219),
#  (',', 1762),
#  ('RB', 1667),
#  ('PRP', 1502),
#  ('CC', 1459),
#  ('VBZ', 1437),
#  ('.', 874),
#  ('VBD', 726),
#  ('PRP$', 645),
#  ('VBP', 602),
#  ('MD', 588),
#  (':', 548),
#  ('(', 536),
#  (')', 533),
#  ('VBN', 525),
#  ('CD', 452),
#  ('WRB', 406),
#  ('WDT', 380),
#  ('RP', 347),
#  ('WP', 189),
#  ('POS', 162),
#  ("''", 104),
#  ('``', 102),
#  ('JJR', 82),
#  ('#', 77),
#  ('EX', 65),
#  ('RBR', 44),
#  ('$', 43),
#  ('NNPS', 40),
#  ('PDT', 40),
#  ('JJS', 16),
#  ('FW', 11),
#  ('RBS', 5),
#  ('SYM', 2)]

# %%
nouns = [i for i in pos_tags if i[1] in ['NNS','NN', 'NNS']]

# %%
verbs = [i for i in pos_tags if i[1] in ['VBG','VB', 'VBZ', 'VBD', 'VBP']]

# %%
noun_count = {}
for i in nouns:
    if i[0] in noun_count:
        noun_count[i[0]] += 1
    else:
        noun_count.update({i[0]:1})

# %%
sorted(noun_count.items(), key = lambda x: x[1], reverse=True)
# Out:
# [('shell', 381),
#  ('file', 268),
#  ('password', 255),
#  ('box', 254),
#  ('files', 201),
#  ('script', 191),
#  ('code', 180),
#  ('reverse', 169),
#  ('root', 117),
#  ('user', 114),
#  ('port', 103),
#  ('source', 101),
#  ('exploit', 100),
#  ('access', 96),
#  ('page', 94),
#  ('credentials', 92),
#  ('users', 92),
#  ('directory', 91),
#  ('way', 91),
#  ('server', 86),
#  ('command', 85),
#  ('application', 83),
#  ('database', 80),
#  ('payload', 75),
#  ('nmap', 69),
#  ('time', 68),
#  ('website', 66),
#  ('web', 65),
#  ('data', 65),
#  ('python', 64),
#  ('injection', 60),
#  ('information', 58),
#  ('execution', 58),
#  ('https', 57),
#  ('key', 56),
#  ('login', 52),
#  ('program', 50),
#  ('version', 50),
#  ('memory', 50),
#  ('webserver', 48),
#  ('admin', 48),
#  ('recon', 48),
#  ('host', 47),
#  ('passwords', 47),
#  ('output', 46),
#  ('error', 45),
#  ('binary', 45),
#  ('function', 45),
#  ('hash', 44),
#  ('account', 44),
#  ('commands', 43),
# ...

# %%
verb_count = {}
for i in verbs:
    if i[0] in verb_count:
        verb_count[i[0]] += 1
    else:
        verb_count.update({i[0]:1})

# %% [markdown]
# NN: noun, common, singular or mass
# NNP: noun, proper, singular
# DT: determiner
# IN: preposition or conjunction, subordinating
# VBG: verb, present participle or gerund
# VB: verb, base form
# VBD: verb, past tense
# TO: "to" as preposition or infinitive marker
# JJ: adjective or numeral, ordinal
# NNS: noun, common, plural
# RB: adverb
# PRP: pronoun, personal
# PRP$: pronoun, possessive
# CC: conjunction, coordinating
# VBZ: verb, present tense, 3rd person singular

# %%
def make_video_summary(vid):
    vid_data = df[df['videoId'] == vid]
    lines = [x for x in vid_data['line']]
    for line in lines:
        
        tokens = word_tokenize(line)
        
        stop_words = set(stopwords.words("english"))
        filtered_tokens = [token for token in tokens if token.lower() not in stop_words] 
        
        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

        pos_tags = pos_tag(tokens)
        
        
        
        print(pos_tags)

# %%
make_video_summary('VofMBg2VLnw')
# Out:
# [('Intro', 'NNP')]
# [('Start', 'NNP'), ('of', 'IN'), ('recon', 'NN'), (',', ','), ('discovering', 'VBG'), ('a', 'DT'), ('bunch', 'NN'), ('of', 'IN'), ('hostnames', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('cert', 'NN')]
# [('Running', 'VBG'), ('wpscan', 'JJ'), ('against', 'IN'), ('blog.travel.htb', 'NN')]
# [('Running', 'VBG'), ('the', 'DT'), ('raft-large-files.txt', 'NN'), ('against', 'IN'), ('blog-dev.travel.htb', 'NN'), ('to', 'TO'), ('discover', 'VB'), ('the', 'DT'), ('git', 'NN'), ('repo', 'NN')]
# [('Using', 'VBG'), ('git-dumper', 'JJ'), ('to', 'TO'), ('download', 'VB'), ('the', 'DT'), ('git', 'NN'), ('repo', 'NN')]
# [('Examining', 'VBG'), ('the', 'DT'), ('git', 'NN'), ('project', 'NN'), ('to', 'TO'), ('discover', 'VB'), ('what', 'WP'), ('it', 'PRP'), ('is', 'VBZ'), ('and', 'CC'), ('where', 'WRB'), ('its', 'PRP$'), ('installed', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('webserver', 'NN')]
# [('Discovering', 'VBG'), ('a', 'DT'), ('debug', 'NN'), ('file', 'NN')]
# ...

# %%
import os
transcript_files = os.listdir('transcripts')

# %%
for file in transcript_files:
    f = open(f"transcripts/{file}", "r")
    print(f.read(15))
# Out:
#  what's going o
#  hey guys this
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  hello I'm Nick
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  let's see look
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  hello I'm Nick
#  hey guys what'
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
#  what's going o
# ...
